# %% [markdown]
# # Pandas Some Basic Function

# %%
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

import pandas as pd
df = pd.read_csv("NYSE_daily_prices_A.csv", parse_dates=['date'])
df.head(5)
# Out:
#   exchange stock_symbol       date  stock_price_open  stock_price_high  \
# 0     NYSE          AEA 2010-02-08              4.42              4.42
# 1     NYSE          ASP 2010-02-08             11.87             12.13
# 2     NYSE          AIT 2010-02-08             21.81             21.81
# 3     NYSE          ATV 2010-02-08              5.91              6.07
# 4     NYSE          ACM 2010-02-08             25.54             26.05
#
#    stock_price_low  stock_price_close  stock_volume  stock_price_adj_close
# 0             4.21               4.24        205500                   4.24
# 1            11.82              11.89         18900                  11.89
# 2            21.28              21.31        103800                  21.31
# 3             5.81               5.81        114400                   5.81
# 4            25.35              25.80       1012600                  25.80

# %%
df['stock_symbol'].value_counts()
# Out:
# AEO     530
# AVA     530
# AVT     530
# ALU     530
# ABK     530
# ARJ     530
# AMB     530
# ALX     530
# AMG     530
# ACI     530
# APA     530
# ARM     530
# ASA     530
# APH     530
# APL     530
# ADM     530
# ATW     530
# AWF     530
# AMX     530
# ASP     530
# AYI     530
# AFE     530
# AES     530
# ACC     530
# AM      530
# ACM     530
# ATU     530
# AWI     530
# ABD     530
# ALV     530
#        ...
# ADC     530
# AHD     530
# AME     530
# ABB     530
# ARD     530
# AGD     530
# AMN     530
# ABC     530
# AMD     530
# APX     530
# ALM     530
# AIV     530
# AAI     530
# AXL     530
# AFG     530
# AUY     530
# AIR     530
# APD     530
# ACE     530
# ACF     530
# ACS     529
# AHC     503
# AFN     495
# AAV     490
# AWK     453
# ALEX    340
# ART      94
# ARI      94
# AV       76
# AOL      51
# Name: stock_symbol, Length: 203, dtype: int64

# %%
df['stock_symbol'].nunique()
# Out:
# 203

# %%
df.shift(5)
# Out:
#        exchange stock_symbol       date  stock_price_open  stock_price_high  \
# 0           NaN          NaN        NaT               NaN               NaN
# 1           NaN          NaN        NaT               NaN               NaN
# 2           NaN          NaN        NaT               NaN               NaN
# 3           NaN          NaN        NaT               NaN               NaN
# 4           NaN          NaN        NaT               NaN               NaN
# 5          NYSE          AEA 2010-02-08              4.42              4.42
# 6          NYSE          ASP 2010-02-08             11.87             12.13
# 7          NYSE          AIT 2010-02-08             21.81             21.81
# 8          NYSE          ATV 2010-02-08              5.91              6.07
# 9          NYSE          ACM 2010-02-08             25.54             26.05
# 10         NYSE          ACH 2010-02-08             23.40             23.57
# ...

# %%
df.plot.hist()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-44-aae26ac4cd3e> in <module>()
# ----> 1 df.plot.hist()
#
# ~\Anaconda3\lib\site-packages\pandas\plotting\_core.py in hist(self, by, bins, **kwds)
#    2773         axes : matplotlib.AxesSubplot or np.array of them
#    2774         """
# -> 2775         return self(kind='hist', by=by, bins=bins, **kwds)
#    2776
#    2777     def kde(self, **kwds):
#
# ~\Anaconda3\lib\site-packages\pandas\plotting\_core.py in __call__(self, x, y, kind, ax, subplots, sharex, sharey, layout, figsize, use_index, title, grid, legend, style, logx, logy, loglog, xticks, yticks, xlim, ylim, rot, fontsize, colormap, table, yerr, xerr, secondary_y, sort_columns, **kwds)
#    2675                           fontsize=fontsize, colormap=colormap, table=table,
#    2676                           yerr=yerr, xerr=xerr, secondary_y=secondary_y,
# ...

# %%
df.head(2)
df1 = df[(df['stock_symbol']=='AEA')]
df1.head(3)
#df['AEA'].plot.scatter('stock_price_open','stock_price_close')

# %%
df[(df['stock_symbol']=='AEA')].plot.scatter(x='stock_price_open',y='stock_price_close')

# %%
df['date'].dt.year.nunique()
# Out:
# 3

# %%
df['date'].dt.year.value_counts()
# Out:
# 2009    50338
# 2008    50053
# 2010     5024
# Name: date, dtype: int64
